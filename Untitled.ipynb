# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
sns.set(style="whitegrid")

d = {'condition': ["1","2","3"], 'percentage of reply \"no\"': [i*100 for i in [0.41666667, 0.07792208, 0.13432836]]}
# tips = sns.load_dataset("tips")

df = pd.DataFrame(data=d)

# %%
# tips

# %%
ax = sns.barplot(x="condition", y='percentage of reply \"no\"', data=df,ci=95.0,errcolor='.26',errwidth=0.01,yerr=[0.1068145*100,0.04172112*100,0.06201744*100])
# ax = sns.barplot(x="day", y="total_bill", data=tips)

# %%
d2 = {'': ["L1-A","L1-D","L1-AD"], 'P(not Flour | Somewhere)': [i*1 for i in [0.75,0.5, 0.625]]}
# tips = sns.load_dataset("tips")

df2 = pd.DataFrame(data=d2)
ax = sns.barplot(x="", y='P(not Flour | Somewhere)', data=df2)

# %%
import dill as pickle
metaphor_to_score_count = pickle.load(open("metaphor_to_score_count.pkl",'rb'))

# %%
import numpy as np
import matplotlib.pyplot as plt
# width of the bars

def compare_l1_baseline(met):
    return metaphor_to_score_count["l1"][met][0]-metaphor_to_score_count["baseline"][met][0]

X_labels = sorted(list(metaphor_to_score_count["l1"]),key=lambda met: compare_l1_baseline(met),reverse=True)[:50]


    
# print(X_labels)
# print(compare_l1_baseline(X_labels[0]))

# raise Exception

barWidth = 0.1
 
# Choose the height of the blue bars
bars1 = [metaphor_to_score_count["l1"][met][0] for met in X_labels]
 
# Choose the height of the cyan bars
bars2 = [metaphor_to_score_count["baseline"][met][0] for met in X_labels]

width=0.5
# The x position of bars
r1 = width*np.arange(len(bars1))
r2 = [x + barWidth for x in r1]

plt.figure(figsize=(20,10))
# Create blue bars
plt.bar(r1, bars1, width = barWidth, color = 'blue', edgecolor = 'black', capsize=7, label='l1')
 
# Create cyan bars
plt.bar(r2, bars2, width = barWidth, color = 'cyan', edgecolor = 'black', capsize=7, label='baseline')
 
# general layout
plt.xticks([width*r + barWidth for r in range(len(bars1))], X_labels,rotation="vertical")
plt.ylabel('height')
plt.legend()
# Out:
# {'corrosive corruption': 26.733333333333334, 'deep-rooted tradition': 51.800000000000004, 'blue obscurity': 24.357142857142858, 'bloated spending': 69.0, 'dim reminder': 45.0625, 'colorful personality': 27.576923076923073, 'colorful remark': 28.900000000000006, 'economic rise': -5.9375, 'civic fabric': 21.199999999999996, 'dead money': 10.428571428571429, 'economic slide': 23.909090909090907, 'deflated pride': -7.75, 'cold justice': -11.600000000000001, 'deflated emotions': -53.9, 'corporate pie': -35.28571428571429, 'dodgy bar': 55.5, 'deep solitude': 37.25, 'cultural strength': 43.5, 'backward area': 34.75, 'dynamic company': 21.25, 'democratic vitality': 0.75, 'economic battle': 30.4375, 'ecological collapse': 32.166666666666664, 'economic muscle': 15.833333333333329, 'chronic poverty': 15.125, 'desolate beauty': 61.7, 'clear-cut solution': 21.299999999999997, 'clouded future': 6.800000000000004, 'deep poverty': -5.799999999999997, 'clear responsibility': 50.85714285714286, 'acute poverty': 19.875, 'deserted friendship': -28.050000000000004, 'blue feelings': -25.909090909090907, 'economic mobility': 0.1428571428571388, 'deeper poverty': -38.15, 'durable middle-class': -7.549999999999997, 'crushing unemployment': -13.5, 'colliding contradiction': 9.111111111111114, 'dimmed prospect': 51.125, 'crushing neglect': 20.0, 'crushing cycle': 4.888888888888886, 'blossoming industry': 97.33333333333334, 'debilitating poverty': -29.25, 'delicious agony': 45.3, 'durable class': 18.9375, 'breakneck expansion': 13.555555555555564, 'blazing desolation': 20.833333333333336, 'balanced growth': 0.13636363636364024, 'deep-rooted belief': 12.125, 'crushing misery': 23.25, 'crisscrossed chaos': -8.214285714285714, 'concentrated poverty': 48.25, 'dark passion': 49.9375, 'aggressive program': 12.333333333333336, 'bottled passion': -10.285714285714285, 'crushing difficulty': 5.875, 'broken hope': 15.777777777777779, 'economic prescription': -28.55, 'ballooning expenditure': 22.999999999999993, 'economic pie': -13.642857142857146, 'dirty desires': -16.5, 'cut-throat competition': -54.57142857142857, 'deepening crisis': 36.4, 'broken melody': 28.500000000000004, 'criminal path': -17.416666666666664, 'dirty deeds': 0.5, 'dissolved time': 11.125, 'deep analysis': -15.500000000000007, 'crippling awkwardness': 34.0, 'dehumanizing poverty': 9.5, 'compassionate budget': 28.8125, 'crushing ignorance': 32.5, 'economic revitalization': 6.8125, 'economic sphere': -0.0714285714285694, 'burning soul': 59.0, 'crushing hunger': 46.142857142857146, 'collapsing health': 0.0, 'cultural impediment': 17.125, 'economic laggard': -0.6666666666666714, 'economic medicine': 6.136363636363633, 'ageless rhythms': 59.33333333333334, 'economic tapestry': 4.357142857142858, 'clear-cut answer': 36.875, 'burdened service': 21.75, 'economic force': -2.6666666666666714, 'economic meltdown': -34.38888888888889, 'cold appearance': 42.75, 'blind optimism': 40.714285714285715, 'deep inequality': 10.599999999999998, 'economic field': 36.0, 'draining expense': 3.9285714285714377, 'cloudy prospect': 25.625, 'dynamic personality': 40.57142857142858, 'backward tradition': 30.416666666666664, 'biting look': -6.916666666666671, 'economic heap': -30.75, 'academic gap': 18.25, 'deep rank': 28.214285714285715, 'crushing effect': 63.25, 'backbreaking rent': -21.749999999999993, 'deflated meaning': 0.0, 'choked gullies': 23.000000000000007, 'deserted relationships': 23.0, 'blind hate': -32.24999999999999, 'acute ignorance': 27.0, 'economic destruction': 15.5, 'deflated joke': 9.5, 'big weakness': 33.33333333333333, 'blind elite': -3.0}
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-55-3ce8bbe9c7dc> in <module>()
#      24 print(mean_differences)
#      25
# ---> 26 raise Exception
#      27
#      28 # print(X_labels)
#
# Exception:

# %%
X_labels = sorted(list(metaphor_to_score_count["l1"]),key=lambda met: compare_l1_baseline(met),reverse=True)[50:]


# print(X_labels)
# print(compare_l1_baseline(X_labels[0]))

# raise Exception

barWidth = 0.1
 
# Choose the height of the blue bars
bars1 = [metaphor_to_score_count["l1"][met][0] for met in X_labels]
 
# Choose the height of the cyan bars
bars2 = [metaphor_to_score_count["baseline"][met][0] for met in X_labels]

width=0.5
# The x position of bars
r1 = width*np.arange(len(bars1))
r2 = [x + barWidth for x in r1]

plt.figure(figsize=(20,10))
# Create blue bars
plt.bar(r1, bars1, width = barWidth, color = 'blue', edgecolor = 'black', capsize=7, label='l1')
 
# Create cyan bars
plt.bar(r2, bars2, width = barWidth, color = 'cyan', edgecolor = 'black', capsize=7, label='baseline')
 
# general layout
plt.xticks([width*r + barWidth for r in range(len(bars1))], X_labels,rotation="vertical")
plt.ylabel('height')
plt.legend()

# %%
print(len(mean_differences))
print(len(metaphor_to_score_count["l1"]))
X_labels = sorted(list(mean_differences),reverse=False,key=lambda x: mean_differences[x])
mean_differences = {}

for met in list(metaphor_to_score_count["baseline"]):
    
    l1_scores = metaphor_to_score_count["l1"][met][0]
    l1_count = metaphor_to_score_count["l1"][met][1]
    
    lit_scores = metaphor_to_score_count["baseline"][met][0]
    lit_count = metaphor_to_score_count["baseline"][met][1]
    
    
    
    mean_differences[met]=(l1_scores/l1_count)-(lit_scores/lit_count)
    

barWidth = 0.5
 
# Choose the height of the blue bars
bars1 = [mean_differences[met] for met in X_labels]
 
# Choose the height of the cyan bars
# bars2 = [metaphor_to_score_count["baseline"][met][0] for met in X_labels]

width=1.0
# The x position of bars
r1 = width*np.arange(len(bars1))
r2 = [x + barWidth for x in r1]

plt.figure(figsize=(20,10))
# Create blue bars
plt.bar(r1, bars1, width = barWidth, color = 'blue', edgecolor = 'black', capsize=7, label='l1')
 
# Create cyan bars
# plt.bar(r2, bars2, width = barWidth, color = 'cyan', edgecolor = 'black', capsize=7, label='baseline')
 
# general layout
plt.xticks([width*r + barWidth for r in range(len(bars1))], X_labels,rotation="vertical")
plt.ylabel('height')
plt.legend()
# Out:
# 109
# 109
