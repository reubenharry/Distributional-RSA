# %%
from __future__ import division
from collections import defaultdict
import scipy
import numpy as np
import pickle
import itertools
from dist_rsa.dbm import *
from dist_rsa.utils.load_data import *
from dist_rsa.utils.helperfunctions import *
from dist_rsa.utils.config import abstract_threshold,concrete_threshold
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

import tensorflow as tf

# vec_size,vec_kind = 25,'glove.twitter.27B.'
vec_size,vec_kind = 300,'glove.6B.'
# freqs = pickle.load(open('dist_rsa/data/google_freqs/freqs','rb'))
nouns,adjs = get_words(with_freqs=False)
vecs = load_vecs(mean=True,pca=False,vec_length=vec_size,vec_type=vec_kind) 

def l1_model(subj,pred):

    print('abstract_threshold',abstract_threshold)
    print('concrete_threshold',concrete_threshold)

    qud_words = [a for a in list(adjs) if adjs[a] < abstract_threshold and a in vecs]

    quds = sorted(qud_words,\
        key=lambda x:scipy.spatial.distance.cosine(vecs[x],np.mean([vecs[pred],vecs[pred]],axis=0)),reverse=False)
        # key=lambda x:freqs[x],reverse=True)

    noun_words = [n for n in nouns if nouns[n] > concrete_threshold and n in vecs]
    possible_utterances = sorted(noun_words,\
        key=lambda x: scipy.spatial.distance.cosine(vecs[x],np.mean([vecs[subj],vecs[subj]],axis=0)),reverse=False)
        # key=lambda x:freqs[x],reverse=True)


    for x in possible_utterances:
        if x not in vecs:
            # print(x,"not in vecs")
            possible_utterances.remove(x)
            # raise Exception("utterance not in vecs")

    quds = quds[:30]
    possible_utterances = possible_utterances[:1000]

    print("QUDS",quds[:10]) 
    print("UTTERANCES:\n",possible_utterances[:10])


    params = Inference_Params(
        vecs=vecs,
        subject=[subj],predicate=pred,
        quds=quds,
        possible_utterances=list(set(possible_utterances).union(set([pred]))),
        sig1=10.0,sig2=1.0,l1_sig1=10.0,
        qud_weight=0.0,freq_weight=0.0,
        number_of_qud_dimensions=1,
        poss_utt_frequencies=defaultdict(lambda:1),
        qud_frequencies=defaultdict(lambda:1),
        rationality=1.0,
        norm_vectors=False,
        heatmap=False,
        resolution=Resolution(span=10,number=100),
        model_type="discrete_mixture",
        )

    run = Dist_RSA_Inference(params)
    run.compute_l1(load=0,save=False)


    out = run.tf_results
    tf.reset_default_graph()
    return out,params

    # world_means = run.world_samples
    # print(world_means[:5],"MEANS")

    # print(results[:5])

    # if not is_baseline:
    #     worldm = run.world_movement("cosine",comparanda=[x for x in qud_words if x in vecs])
    #     # print("\nworld\n",worldm[:5])
    # else: worldm = None
        # out.write("\nWORLD MOVEMENT:\n")
        # out.write(str(worldm))
    # print("WORLD MOVEMENT WITH PROJECTION\n:",run.world_movement("cosine",comparanda=[x for x in quds if x in vecs],do_projection=True)[:50])
    # print("BASELINE:\n",sorted(qud_words,\
    #     key=lambda x:scipy.spatial.distance.cosine(vecs[x],np.mean([vecs[subj],vecs[pred]],axis=0)),reverse=False)[:5])

    # demarg = demarginalize_product_space(results)
    # print("\ndemarginalized:\n,",demarg[:5])
    # out.write("\ndemarginalized:\n")
    # out.write((str(demarg)))

    # params.number_of_qud_dimensions=1
    # run = Dist_RSA_Inference(params)
    # run.compute_l1(load=0,save=False)
    # results2 = run.qud_results()
    # # print("\n1d results\n",results2[:10])
    # one_d = results2
    # one_d=None

if __name__ == "__main__":

    

    # for x in range(1):
    #     l1_model(("father","shark",0.5,0.5,1.0,0,100,False))
    subj,pred = "man","shark"
    result,params = l1_model(subj=subj,pred=pred)


        # print()


        # print(l1_model(subj="man",pred="swimmer"))

        # print(scipy.spatial.distance.cosine(vecs['man']-means1[0],vecs['man']-means2[0]))
        # worlds,quds=l1_model(("wall","frog",1.0,1.0,1.0,0,1000,True))
        # print(quds[:10])
# Out:
# loading vecs (load vecs): glove.6B.mean_vecs300
# abstract_threshold 2.5
# concrete_threshold 3.0
#   0%|          | 0/30 [00:00<?, ?it/s]
# QUDS ['wild', 'rare', 'similar', 'latest', 'prized', 'good', 'famous', 'great', 'mysterious', 'other']
# UTTERANCES:
#  ['man', 'woman', 'person', 'boy', 'men', 'father', 'girl', 'guy', 'hand', 'brother']
# RESOLUTION. SIZE: 100 AMOUNT: 0.1
# subject: ['man']
# predicate shark
# SIGs 1&2: 10.0 1.0
# L1 SIG 10.0
# number of qud dimensions: 1
# rationality: 1.0
# Running discrete_mixture RSA with 1000 possible utterances and 30
# RUNNING DISCRETE MIXTURE MODEL
# qud_combinations 30 [['bad'], ['best'], ['common'], ['dangerous'], ['exotic'], ['famous'], ['good'], ['great'], ['latest'], ['likely'], ['lone'], ['mega'], ['mysterious'], ['natural'], ['occasional'], ['other'], ['particular'], ['prized'], ['rare'], ['similar'], ['spectacular'], ['strange'], ['supposed'], ['true'], ['typical'], ['uncommon'], ['unusual'], ['usual'], ['vulnerable'], ['wild']]
# quds 30
# SIZE,AMOUNT 100 0.1
# 100%|██████████| 30/30 [02:22<00:00,  4.74s/it]
# time: 142.18440580368042
# time: 38.018354177474976
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.3290808]] [[8.480037]]
# 0 0 2.3290808 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.2691221]] [[8.275655]]
# 0 1 3.2691221 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.598563]] [[8.728909]]
# 0 2 2.598563 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.7142646]] [[8.562244]]
# 0 3 2.7142646 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.7955616]] [[7.799782]]
# 0 4 1.7955616 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.2109768]] [[8.719313]]
# 0 5 3.2109768 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.37283]] [[8.427352]]
# 0 6 3.37283 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.4600685]] [[8.336226]]
# 0 7 3.4600685 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.880724]] [[8.883498]]
# 0 8 2.880724 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.9816048]] [[8.680493]]
# 0 9 2.9816048 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.3369622]] [[8.66503]]
# 0 10 3.3369622 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.209224]] [[9.481523]]
# 0 11 2.209224 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.5862067]] [[9.150454]]
# 0 12 3.5862067 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.566869]] [[8.465471]]
# 0 13 2.566869 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.3453994]] [[8.749655]]
# 0 14 2.3453994 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.1273715]] [[8.346605]]
# 0 15 3.1273715 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.885793]] [[8.721423]]
# 0 16 2.885793 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.7576038]] [[9.205916]]
# 0 17 1.7576038 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.6717525]] [[8.02837]]
# 0 18 2.6717525 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.9311152]] [[8.672713]]
# 0 19 2.9311152 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.084299]] [[8.758308]]
# 0 20 2.084299 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.907239]] [[8.4206505]]
# 0 21 2.907239 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.0513756]] [[8.845762]]
# 0 22 3.0513756 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.2876015]] [[8.660994]]
# 0 23 3.2876015 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.821689]] [[8.739811]]
# 0 24 2.821689 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.1593874]] [[8.772289]]
# 0 25 2.1593874 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.8490555]] [[8.584656]]
# 0 26 2.8490555 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.5777457]] [[8.708935]]
# 0 27 2.5777457 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.0467806]] [[8.962987]]
# 0 28 2.0467806 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.362017]] [[2.3696842]]
# 0 29 2.362017 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.4207451]] [[8.422225]]
# 1 0 2.4207451 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.7233052]] [[8.21007]]
# 1 1 1.7233052 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.1183786]] [[8.680563]]
# 1 2 2.1183786 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.4404411]] [[8.50756]]
# 1 3 2.4404411 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.3294439]] [[7.716097]]
# 1 4 1.3294439 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.4307804]] [[8.670602]]
# 1 5 2.4307804 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.6703737]] [[8.367537]]
# 1 6 2.6703737 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.7062984]] [[8.272944]]
# 1 7 2.7062984 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.392129]] [[8.841032]]
# 1 8 2.392129 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.4850786]] [[8.630306]]
# 1 9 2.4850786 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.7092128]] [[8.614254]]
# 1 10 2.7092128 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.9141821]] [[9.461802]]
# 1 11 1.9141821 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.432012]] [[9.118141]]
# 1 12 3.432012 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.976287]] [[8.407105]]
# 1 13 1.976287 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.047041]] [[8.702098]]
# 1 14 2.047041 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.445683]] [[8.283719]]
# 1 15 2.445683 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.2561367]] [[8.672792]]
# 1 16 2.2561367 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.1737788]] [[9.175714]]
# 1 17 1.1737788 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.1975641]] [[7.953379]]
# 1 18 2.1975641 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.466243]] [[8.62223]]
# 1 19 2.466243 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.5925137]] [[8.711081]]
# 1 20 1.5925137 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.7433124]] [[8.36058]]
# 1 21 2.7433124 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.5964553]] [[8.801861]]
# 1 22 2.5964553 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.605977]] [[8.6100645]]
# 1 23 2.605977 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.2609758]] [[8.691879]]
# 1 24 2.2609758 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.7579707]] [[8.725594]]
# 1 25 1.7579707 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.386533]] [[8.530823]]
# 1 26 2.386533 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.1374276]] [[8.659829]]
# 1 27 2.1374276 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.8103646]] [[8.923544]]
# 1 28 1.8103646 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.883976]] [[2.0794654]]
# 1 29 1.883976 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.5661914]] [[8.476789]]
# 2 0 3.5661914 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.855351]] [[8.271972]]
# 2 1 3.855351 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.6130233]] [[8.726193]]
# 2 2 2.6130233 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.2957602]] [[8.559174]]
# 2 3 3.2957602 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.975508]] [[7.7950816]]
# 2 4 1.975508 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.573006]] [[8.716577]]
# 2 5 3.573006 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.146414]] [[8.423992]]
# 2 6 4.146414 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.9297984]] [[8.332672]]
# 2 7 3.9297984 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.4070249]] [[8.881113]]
# 2 8 3.4070249 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.4887419]] [[8.677675]]
# 2 9 3.4887419 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.5808272]] [[8.662178]]
# 2 10 3.5808272 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.5435705]] [[9.480414]]
# 2 11 2.5435705 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.9893308]] [[9.148639]]
# 2 12 3.9893308 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.825743]] [[8.462193]]
# 2 13 2.825743 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.762614]] [[8.746984]]
# 2 14 2.762614 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.5099864]] [[8.343073]]
# 2 15 3.5099864 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.2481287]] [[8.718692]]
# 2 16 3.2481287 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.9241259]] [[9.20422]]
# 2 17 1.9241259 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.9382274]] [[8.024158]]
# 2 18 2.9382274 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.2463803]] [[8.669878]]
# 2 19 3.2463803 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.5338707]] [[8.755656]]
# 2 20 2.5338707 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.4965632]] [[8.417276]]
# 2 21 3.4965632 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.6887116]] [[8.843296]]
# 2 22 3.6887116 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.7046895]] [[8.658133]]
# 2 23 3.7046895 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.1077876]] [[8.737119]]
# 2 24 3.1077876 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.3129852]] [[8.769667]]
# 2 25 2.3129852 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.2083461]] [[8.581632]]
# 2 26 3.2083461 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.0062966]] [[8.706177]]
# 2 27 3.0062966 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.4448838]] [[8.960772]]
# 2 28 2.4448838 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.767578]] [[2.353383]]
# 2 29 2.767578 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.379619]] [[8.506816]]
# 3 0 3.379619 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.7791169]] [[8.306036]]
# 3 1 3.7791169 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.9245741]] [[8.751304]]
# 3 2 2.9245741 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.7177463]] [[8.587576]]
# 3 3 2.7177463 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.8912889]] [[7.8385468]]
# 3 4 1.8912889 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.5553036]] [[8.741877]]
# 3 5 3.5553036 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.088054]] [[8.45506]]
# 3 6 4.088054 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.8979754]] [[8.36554]]
# 3 7 3.8979754 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.3092413]] [[8.90317]]
# 3 8 3.3092413 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.3771396]] [[8.703742]]
# 3 9 3.3771396 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.5548637]] [[8.68855]]
# 3 10 3.5548637 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.4991546]] [[9.490657]]
# 3 11 2.4991546 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.815436]] [[9.1654215]]
# 3 12 3.815436 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.8118052]] [[8.492507]]
# 3 13 2.8118052 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.7372987]] [[8.771685]]
# 3 14 2.7372987 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.523034]] [[8.375736]]
# 3 15 3.523034 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.2804978]] [[8.74395]]
# 3 16 3.2804978 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.9076483]] [[9.219907]]
# 3 17 1.9076483 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.906169]] [[8.0631075]]
# 3 18 2.906169 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.3223348]] [[8.696098]]
# 3 19 3.3223348 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.3809047]] [[8.780186]]
# 3 20 2.3809047 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.305251]] [[8.448477]]
# 3 21 3.305251 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.584018]] [[8.866098]]
# 3 22 3.584018 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.6911767]] [[8.684585]]
# 3 23 3.6911767 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.211212]] [[8.762013]]
# 3 24 3.211212 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.4069476]] [[8.79392]]
# 3 25 2.4069476 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.146424]] [[8.6095915]]
# 3 26 3.146424 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.023489]] [[8.731682]]
# 3 27 3.023489 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.2160237]] [[8.981257]]
# 3 28 2.2160237 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.6695635]] [[2.5041194]]
# 3 29 2.6695635 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.455851]] [[8.586823]]
# 4 0 4.455851 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.8770566]] [[8.396801]]
# 4 1 4.8770566 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.0808115]] [[8.818211]]
# 4 2 4.0808115 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.3791094]] [[8.663256]]
# 4 3 4.3791094 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.958067]] [[7.9543605]]
# 4 4 3.958067 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.6390424]] [[8.809289]]
# 4 5 4.6390424 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[5.1937447]] [[8.53784]]
# 4 6 5.1937447 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.9464507]] [[8.453116]]
# 4 7 4.9464507 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.244739]] [[8.96194]]
# 4 8 4.244739 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.495743]] [[8.773197]]
# 4 9 4.495743 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.212043]] [[8.75882]]
# 4 10 4.212043 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.0885563]] [[9.517948]]
# 4 11 3.0885563 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[5.0585966]] [[9.210139]]
# 4 12 5.0585966 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.9654136]] [[8.573281]]
# 4 13 3.9654136 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.6988037]] [[8.8375]]
# 4 14 3.6988037 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.848933]] [[8.462767]]
# 4 15 4.848933 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.5156183]] [[8.811251]]
# 4 16 4.5156183 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.92455]] [[9.261705]]
# 4 17 2.92455 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.1904497]] [[8.166889]]
# 4 18 4.1904497 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.4788256]] [[8.765964]]
# 4 19 4.4788256 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.3939524]] [[8.845545]]
# 4 20 3.3939524 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.7129803]] [[8.53161]]
# 4 21 4.7129803 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.5642548]] [[8.926854]]
# 4 22 4.5642548 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.766564]] [[8.755067]]
# 4 23 4.766564 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.2803082]] [[8.828346]]
# 4 24 4.2803082 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.5976434]] [[8.858543]]
# 4 25 3.5976434 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.5565305]] [[8.684092]]
# 4 26 4.5565305 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.0543013]] [[8.799641]]
# 4 27 4.0543013 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.2991016]] [[9.035843]]
# 4 28 3.2991016 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.9693444]] [[2.9057598]]
# 4 29 3.9693444 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.3052468]] [[8.51926]]
# 5 0 3.3052468 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.3980196]] [[8.320153]]
# 5 1 3.3980196 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.7162404]] [[8.76171]]
# 5 2 2.7162404 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.1008584]] [[8.599347]]
# 5 3 3.1008584 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.699521]] [[7.85656]]
# 5 4 1.699521 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.5252392]] [[8.752362]]
# 5 5 2.5252392 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.851698]] [[8.467936]]
# 5 6 3.851698 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.4282846]] [[8.379161]]
# 5 7 3.4282846 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.1064856]] [[8.912311]]
# 5 8 3.1064856 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.314154]] [[8.714544]]
# 5 9 3.314154 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.2758148]] [[8.699479]]
# 5 10 3.2758148 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.2746158]] [[9.494902]]
# 5 11 2.2746158 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.639059]] [[9.172377]]
# 5 12 3.639059 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.6159892]] [[8.505071]]
# 5 13 2.6159892 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.5389144]] [[8.781921]]
# 5 14 2.5389144 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.2299497]] [[8.389273]]
# 5 15 3.2299497 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.971147]] [[8.754417]]
# 5 16 2.971147 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.5841718]] [[9.226408]]
# 5 17 1.5841718 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.6723588]] [[8.079249]]
# 5 18 2.6723588 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.0112345]] [[8.7069645]]
# 5 19 3.0112345 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.0810637]] [[8.790351]]
# 5 20 2.0810637 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.2124705]] [[8.461407]]
# 5 21 3.2124705 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.4101076]] [[8.875548]]
# 5 22 3.4101076 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.4260323]] [[8.695547]]
# 5 23 3.4260323 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.8884199]] [[8.772331]]
# 5 24 2.8884199 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.2568197]] [[8.803971]]
# 5 25 2.2568197 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.941889]] [[8.62118]]
# 5 26 2.941889 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.87305]] [[8.742252]]
# 5 27 2.87305 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.3550851]] [[8.989748]]
# 5 28 2.3550851 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.5030172]] [[2.5665894]]
# 5 29 2.5030172 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.1723635]] [[8.44831]]
# 6 0 2.1723635 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.462474]] [[8.239663]]
# 6 1 2.462474 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.0148811]] [[8.702377]]
# 6 2 2.0148811 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.4164472]] [[8.532234]]
# 6 3 2.4164472 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.4614297]] [[7.7538567]]
# 6 4 1.4614297 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.7063193]] [[8.692581]]
# 6 5 2.7063193 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.2756262]] [[8.3945265]]
# 6 6 2.2756262 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.579908]] [[8.301498]]
# 6 7 2.579908 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.5493813]] [[8.860193]]
# 6 8 2.5493813 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.4961507]] [[8.652951]]
# 6 9 2.4961507 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.9343817]] [[8.637165]]
# 6 10 2.9343817 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.0358539]] [[9.4707]]
# 6 11 2.0358539 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.39817]] [[9.132721]]
# 6 12 3.39817 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.024172]] [[8.43344]]
# 6 13 2.024172 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.9280791]] [[8.7235565]]
# 6 14 1.9280791 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.5459442]] [[8.312094]]
# 6 15 2.5459442 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.2786705]] [[8.694736]]
# 6 16 2.2786705 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.2834936]] [[9.189342]]
# 6 17 1.2834936 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.1643648]] [[7.987216]]
# 6 18 2.1643648 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.413983]] [[8.645009]]
# 6 19 2.413983 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.6246336]] [[8.73239]]
# 6 20 1.6246336 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.604905]] [[8.387685]]
# 6 21 2.604905 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.4845104]] [[8.82167]]
# 6 22 2.4845104 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.591609]] [[8.633044]]
# 6 23 2.591609 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.291962]] [[8.713507]]
# 6 24 2.291962 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.656424]] [[8.746663]]
# 6 25 1.656424 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.3310885]] [[8.555113]]
# 6 26 2.3310885 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.986329]] [[8.681987]]
# 6 27 1.986329 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.7617543]] [[8.941341]]
# 6 28 1.7617543 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.0263193]] [[2.2104163]]
# 6 29 2.0263193 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.8677018]] [[8.468214]]
# 7 0 2.8677018 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.975144]] [[8.262243]]
# 7 1 2.975144 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.3179405]] [[8.719023]]
# 7 2 2.3179405 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.7398472]] [[8.551063]]
# 7 3 2.7398472 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.6014318]] [[7.782669]]
# 7 4 1.6014318 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.6673038]] [[8.7093525]]
# 7 5 2.6673038 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.120824]] [[8.41512]]
# 7 6 3.120824 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.4145288]] [[8.323286]]
# 7 7 2.4145288 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.8483925]] [[8.874815]]
# 7 8 2.8483925 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.896428]] [[8.670231]]
# 7 9 2.896428 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.1754832]] [[8.654647]]
# 7 10 3.1754832 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.0863557]] [[9.477489]]
# 7 11 2.0863557 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.4846168]] [[9.1438465]]
# 7 12 3.4846168 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.187319]] [[8.453536]]
# 7 13 2.187319 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.243919]] [[8.73993]]
# 7 14 2.243919 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.8371434]] [[8.333746]]
# 7 15 2.8371434 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.516195]] [[8.711479]]
# 7 16 2.516195 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.3860493]] [[9.19974]]
# 7 17 1.3860493 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.3703346]] [[8.013035]]
# 7 18 2.3703346 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.6896389]] [[8.66239]]
# 7 19 2.6896389 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.7835959]] [[8.748651]]
# 7 20 1.7835959 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.904242]] [[8.408367]]
# 7 21 2.904242 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.979658]] [[8.836784]]
# 7 22 2.979658 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.8837996]] [[8.6505785]]
# 7 23 2.8837996 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.6276922]] [[8.730009]]
# 7 24 2.6276922 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.8518777]] [[8.76274]]
# 7 25 1.8518777 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.59607]] [[8.5736475]]
# 7 26 2.59607 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.5162308]] [[8.698894]]
# 7 27 2.5162308 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.0387466]] [[8.954921]]
# 7 28 2.0387466 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.176387]] [[2.310337]]
# 7 29 2.176387 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.3463564]] [[8.432919]]
# 8 0 3.3463564 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.650787]] [[8.222202]]
# 8 1 3.650787 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.8803794]] [[8.689506]]
# 8 2 2.8803794 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.148089]] [[8.517675]]
# 8 3 3.148089 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.9824121]] [[7.731577]]
# 8 4 1.9824121 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.431303]] [[8.679613]]
# 8 5 3.431303 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.0318894]] [[8.378601]]
# 8 6 4.0318894 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.839796]] [[8.284651]]
# 8 7 3.839796 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.6777835]] [[8.848887]]
# 8 8 2.6777835 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.2402153]] [[8.63959]]
# 8 9 3.2402153 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.4396887]] [[8.623647]]
# 8 10 3.4396887 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.2794676]] [[9.465449]]
# 8 11 2.2794676 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.7956793]] [[9.124119]]
# 8 12 3.7956793 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.7960348]] [[8.417902]]
# 8 13 2.7960348 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.655455]] [[8.710896]]
# 8 14 2.655455 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.4224288]] [[8.295351]]
# 8 15 3.4224288 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.1862218]] [[8.681788]]
# 8 16 3.1862218 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.8627933]] [[9.1813]]
# 8 17 1.8627933 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.844132]] [[7.967251]]
# 8 18 2.844132 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.105908]] [[8.631568]]
# 8 19 3.105908 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.2593296]] [[8.719817]]
# 8 20 2.2593296 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.34244]] [[8.371693]]
# 8 21 3.34244 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.497931]] [[8.809981]]
# 8 22 3.497931 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.6221306]] [[8.619485]]
# 8 23 3.6221306 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.0425825]] [[8.700746]]
# 8 24 3.0425825 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.4322658]] [[8.734231]]
# 8 25 2.4322658 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.0506413]] [[8.540781]]
# 8 26 3.0506413 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.890332]] [[8.668913]]
# 8 27 2.890332 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.3461928]] [[8.9308405]]
# 8 28 2.3461928 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.6660216]] [[2.13315]]
# 8 29 2.6660216 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.7614455]] [[8.400465]]
# 9 0 2.7614455 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.0939488]] [[8.185385]]
# 9 1 3.0939488 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.2263167]] [[8.662366]]
# 9 2 2.2263167 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.4955683]] [[8.486978]]
# 9 3 2.4955683 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.6207172]] [[7.684599]]
# 9 4 1.6207172 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.0601282]] [[8.652268]]
# 9 5 3.0601282 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.364486]] [[8.345022]]
# 9 6 3.364486 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.2841132]] [[8.249126]]
# 9 7 3.2841132 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.4868407]] [[8.825048]]
# 9 8 2.4868407 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.9406552]] [[8.611417]]
# 9 9 1.9406552 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.0130587]] [[8.595143]]
# 9 10 3.0130587 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.1141593]] [[9.454379]]
# 9 11 2.1141593 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.4547625]] [[9.105979]]
# 9 12 3.4547625 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.228533]] [[8.385138]]
# 9 13 2.228533 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.2719598]] [[8.684198]]
# 9 14 2.2719598 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.655715]] [[8.260049]]
# 9 15 2.655715 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.496435]] [[8.654489]]
# 9 16 2.496435 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.4752722]] [[9.164346]]
# 9 17 1.4752722 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.35042]] [[7.9251537]]
# 9 18 2.35042 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.4339166]] [[8.603229]]
# 9 19 2.4339166 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.9661347]] [[8.693305]]
# 9 20 1.9661347 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.0192306]] [[8.337971]]
# 9 21 3.0192306 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.7392492]] [[8.7853365]]
# 9 22 2.7392492 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.9720457]] [[8.590896]]
# 9 23 2.9720457 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.5475113]] [[8.673839]]
# 9 24 2.5475113 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.8844925]] [[8.708017]]
# 9 25 1.8844925 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.5096679]] [[8.510561]]
# 9 26 2.5096679 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.303954]] [[8.641347]]
# 9 27 2.303954 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.6211817]] [[8.908698]]
# 9 28 1.6211817 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.2518077]] [[1.970231]]
# 9 29 2.2518077 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.7175648]] [[8.622425]]
# 10 0 3.7175648 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.9265947]] [[8.43719]]
# 10 1 3.9265947 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.1364946]] [[8.847983]]
# 10 2 3.1364946 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.4483018]] [[8.696933]]
# 10 3 3.4483018 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.1489286]] [[8.005897]]
# 10 4 2.1489286 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.652302]] [[8.839287]]
# 10 5 3.652302 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.324274]] [[8.5746765]]
# 10 6 4.324274 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.10907]] [[8.492087]]
# 10 7 4.10907 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.4983792]] [[8.988091]]
# 10 8 3.4983792 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.6421092]] [[8.804104]]
# 10 9 3.6421092 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.1615775]] [[8.790089]]
# 10 10 3.1615775 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.4970298]] [[9.530092]]
# 10 11 2.4970298 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.0345635]] [[9.230039]]
# 10 12 4.0345635 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.0054097]] [[8.609224]]
# 10 13 3.0054097 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.8266103]] [[8.866786]]
# 10 14 2.8266103 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.7488837]] [[8.501493]]
# 10 15 3.7488837 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.5133877]] [[8.841199]]
# 10 16 3.5133877 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.9822327]] [[9.280306]]
# 10 17 1.9822327 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.0845184]] [[8.213071]]
# 10 18 3.0845184 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.5341775]] [[8.797052]]
# 10 19 3.5341775 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.5434334]] [[8.874629]]
# 10 20 2.5434334 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.6039956]] [[8.568603]]
# 10 21 3.6039956 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.8243709]] [[8.95389]]
# 10 22 3.8243709 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.864067]] [[8.78643]]
# 10 23 3.864067 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.328805]] [[8.857864]]
# 10 24 3.328805 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.6324944]] [[8.8873005]]
# 10 25 2.6324944 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.4269412]] [[8.717243]]
# 10 26 3.4269412 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.2279844]] [[8.829881]]
# 10 27 3.2279844 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.5654185]] [[9.060133]]
# 10 28 2.5654185 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.7921658]] [[3.084485]]
# 10 29 2.7921658 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.4401946]] [[8.639078]]
# 11 0 4.4401946 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.7467356]] [[8.456081]]
# 11 1 4.7467356 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.739997]] [[8.861909]]
# 11 2 3.739997 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.030447]] [[8.712684]]
# 11 3 4.030447 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.656381]] [[8.030002]]
# 11 4 2.656381 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.4336605]] [[8.853317]]
# 11 5 4.4336605 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[5.063167]] [[8.591906]]
# 11 6 5.063167 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.86826]] [[8.510315]]
# 11 7 4.86826 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.4047284]] [[9.000323]]
# 11 8 4.4047284 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.413545]] [[8.818561]]
# 11 9 4.413545 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.360623]] [[8.804714]]
# 11 10 4.360623 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.3125296]] [[9.535773]]
# 11 11 4.3125296 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.7130847]] [[9.239346]]
# 11 12 4.7130847 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.7163439]] [[8.626036]]
# 11 13 3.7163439 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.4512239]] [[8.880485]]
# 11 14 3.4512239 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.616606]] [[8.5196085]]
# 11 15 4.616606 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.290178]] [[8.8552065]]
# 11 16 4.290178 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.4379153]] [[9.289005]]
# 11 17 2.4379153 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.8071773]] [[8.234672]]
# 11 18 3.8071773 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.386035]] [[8.811594]]
# 11 19 4.386035 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.2654436]] [[8.888233]]
# 11 20 3.2654436 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.2314153]] [[8.585906]]
# 11 21 4.2314153 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# ...
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.6384153]] [[8.269026]]
# 26 1 3.6384153 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.665173]] [[8.724022]]
# 26 2 2.665173 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.0090413]] [[8.556717]]
# 26 3 3.0090413 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.6746058]] [[7.7913227]]
# 26 4 1.6746058 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.3233156]] [[8.714389]]
# 26 5 3.3233156 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.9172673]] [[8.421306]]
# 26 6 3.9172673 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.6958642]] [[8.32983]]
# 26 7 3.6958642 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.0838406]] [[8.879206]]
# 26 8 3.0838406 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.2456803]] [[8.675421]]
# 26 9 3.2456803 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.4298131]] [[8.659897]]
# 26 10 3.4298131 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.3753424]] [[9.479528]]
# 26 11 2.3753424 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.6480656]] [[9.147187]]
# 26 12 3.6480656 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.5978487]] [[8.459571]]
# 26 13 2.5978487 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.4825811]] [[8.744848]]
# 26 14 2.4825811 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.322446]] [[8.340249]]
# 26 15 3.322446 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.9584866]] [[8.716508]]
# 26 16 2.9584866 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.7791567]] [[9.202864]]
# 26 17 1.7791567 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.5259619]] [[8.02079]]
# 26 18 2.5259619 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.9289129]] [[8.66761]]
# 26 19 2.9289129 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.169956]] [[8.753534]]
# 26 20 2.169956 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.9962292]] [[8.414578]]
# 26 21 2.9962292 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.4820962]] [[8.841325]]
# 26 22 3.4820962 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.5282462]] [[8.655846]]
# 26 23 3.5282462 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.8020597]] [[8.734966]]
# 26 24 2.8020597 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.9727652]] [[8.76757]]
# 26 25 1.9727652 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.5001822]] [[8.579214]]
# 26 26 2.5001822 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.7134933]] [[8.703972]]
# 26 27 2.7134933 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.2882664]] [[8.959]]
# 26 28 2.2882664 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.5745516]] [[2.3403482]]
# 26 29 2.5745516 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.1686568]] [[8.45657]]
# 27 0 3.1686568 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.4968803]] [[8.249033]]
# 27 1 3.4968803 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.563783]] [[8.709285]]
# 27 2 2.563783 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.0299642]] [[8.540048]]
# 27 3 3.0299642 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.7707762]] [[7.765813]]
# 27 4 1.7707762 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.3549085]] [[8.69954]]
# 27 5 3.3549085 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.6987598]] [[8.403072]]
# 27 6 3.6987598 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.6647234]] [[8.310539]]
# 27 7 3.6647234 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.0298603]] [[8.866261]]
# 27 8 3.0298603 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.113875]] [[8.660122]]
# 27 9 3.113875 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.4054046]] [[8.64442]]
# 27 10 3.4054046 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.2879615]] [[9.473517]]
# 27 11 2.2879615 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.775149]] [[9.137338]]
# 27 12 3.775149 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.5764844]] [[8.441779]]
# 27 13 2.5764844 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.3045835]] [[8.730351]]
# 27 14 2.3045835 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.2124438]] [[8.321078]]
# 27 15 3.2124438 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.9554608]] [[8.701683]]
# 27 16 2.9554608 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[1.7998192]] [[9.193657]]
# 27 17 1.7998192 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.7216063]] [[7.99793]]
# 27 18 2.7216063 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.9286146]] [[8.652222]]
# 27 19 2.9286146 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.2009869]] [[8.739139]]
# 27 20 2.2009869 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.1694036]] [[8.396267]]
# 27 21 3.1694036 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.310909]] [[8.827942]]
# 27 22 3.310909 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.4184978]] [[8.640321]]
# 27 23 3.4184978 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.5699577]] [[8.720355]]
# 27 24 2.5699577 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.1335714]] [[8.753335]]
# 27 25 2.1335714 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.7852337]] [[8.562804]]
# 27 26 2.7852337 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.0119526]] [[8.689002]]
# 27 27 2.0119526 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.2923136]] [[8.946977]]
# 27 28 2.2923136 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.4914763]] [[2.2518802]]
# 27 29 2.4914763 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.9600444]] [[8.494825]]
# 28 0 3.9600444 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.257908]] [[8.292433]]
# 28 1 4.257908 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.3992188]] [[8.741277]]
# 28 2 3.3992188 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.6930456]] [[8.576234]]
# 28 3 3.6930456 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.3173668]] [[7.8211904]]
# 28 4 2.3173668 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.947122]] [[8.731774]]
# 28 5 3.947122 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.618049]] [[8.442654]]
# 28 6 4.618049 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.3680806]] [[8.352415]]
# 28 7 4.3680806 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.7787123]] [[8.894362]]
# 28 8 3.7787123 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.961342]] [[8.693333]]
# 28 9 3.961342 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.8634827]] [[8.67802]]
# 28 10 3.8634827 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.7291982]] [[9.486567]]
# 28 11 2.7291982 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.2845445]] [[9.15872]]
# 28 12 4.2845445 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.2498684]] [[8.480402]]
# 28 13 3.2498684 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.1268306]] [[8.761821]]
# 28 14 3.1268306 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.0632243]] [[8.362693]]
# 28 15 4.0632243 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.8083453]] [[8.733864]]
# 28 16 3.8083453 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.2001007]] [[9.213643]]
# 28 17 2.2001007 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.400511]] [[8.047554]]
# 28 18 3.400511 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.8080535]] [[8.685628]]
# 28 19 3.8080535 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.7927253]] [[8.7703905]]
# 28 20 2.7927253 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.8332102]] [[8.436018]]
# 28 21 3.8332102 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.0938478]] [[8.856993]]
# 28 22 4.0938478 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.178247]] [[8.674022]]
# 28 23 4.178247 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.6081712]] [[8.752072]]
# 28 24 3.6081712 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.851215]] [[8.784235]]
# 28 25 2.851215 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.6938283]] [[8.598427]]
# 28 26 3.6938283 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.4583955]] [[8.721498]]
# 28 27 3.4583955 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.8250885]] [[8.973077]]
# 28 28 2.8250885 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.099177]] [[2.4439278]]
# 28 29 3.099177 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.567451]] [[8.464547]]
# 29 0 4.567451 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.9102497]] [[8.258082]]
# 29 1 4.9102497 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.953878]] [[8.715956]]
# 29 2 3.953878 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.2755632]] [[8.547593]]
# 29 3 4.2755632 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.060423]] [[7.77736]]
# 29 4 3.060423 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.5111756]] [[8.706262]]
# 29 5 4.5111756 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[5.2371664]] [[8.411325]]
# 29 6 5.2371664 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[5.0086784]] [[8.319271]]
# 29 7 5.0086784 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.2989254]] [[8.872121]]
# 29 8 4.2989254 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.518578]] [[8.667047]]
# 29 9 4.518578 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.4395256]] [[8.651425]]
# 29 10 4.4395256 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.087011]] [[9.476238]]
# 29 11 3.087011 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.7366686]] [[9.141796]]
# 29 12 4.7366686 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.8600187]] [[8.449833]]
# 29 13 3.8600187 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.683378]] [[8.736913]]
# 29 14 3.683378 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.6927824]] [[8.329756]]
# 29 15 4.6927824 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.3592434]] [[8.708394]]
# 29 16 4.3592434 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[2.639684]] [[9.1978245]]
# 29 17 2.639684 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.0951214]] [[8.008278]]
# 29 18 4.0951214 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.374527]] [[8.659187]]
# 29 19 4.374527 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.3482113]] [[8.745655]]
# 29 20 3.3482113 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.4594946]] [[8.404556]]
# 29 21 4.4594946 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.6208315]] [[8.834]]
# 29 22 4.6208315 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.749628]] [[8.647348]]
# 29 23 4.749628 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.162663]] [[8.726969]]
# 29 24 4.162663 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.3979712]] [[8.759778]]
# 29 25 3.3979712 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.2812304]] [[8.570232]]
# 29 26 4.2812304 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.02263]] [[8.695778]]
# 29 27 4.02263 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[3.292228]] [[8.952418]]
# 29 28 3.292228 THING THING
#
# (300, 1)
# (300, 1)
# (300, 300) (300, 1)
# (300,) IMPORTANT SHAPE
# mean and variance [[4.495347]] [[2.2919254]]
# 29 29 4.495347 THING THING
#
# time: 17.810059785842896

# %%
result
# Out:
# (None,
#  [(['prized'], 'n/a', 0.09796561),
#   (['mega'], 'n/a', 0.06303169),
#   (['wild'], 'n/a', 0.057306994),
#   (['exotic'], 'n/a', 0.051775713),
#   (['rare'], 'n/a', 0.045703065),
#   (['occasional'], 'n/a', 0.032453854),
#   (['spectacular'], 'n/a', 0.031315517),
#   (['uncommon'], 'n/a', 0.031147767),
#   (['mysterious'], 'n/a', 0.03094501),
#   (['vulnerable'], 'n/a', 0.029667033),
#   (['particular'], 'n/a', 0.029296359),
#   (['lone'], 'n/a', 0.028849203),
#   (['supposed'], 'n/a', 0.028093327),
#   (['best'], 'n/a', 0.027737236),
#   (['other'], 'n/a', 0.027667912),
#   (['likely'], 'n/a', 0.02734724),
#   (['usual'], 'n/a', 0.026987422),
#   (['typical'], 'n/a', 0.026730051),
#   (['common'], 'n/a', 0.026450904),
#   (['natural'], 'n/a', 0.026110848),
#   (['similar'], 'n/a', 0.02609651),
#   (['dangerous'], 'n/a', 0.026005877),
#   (['unusual'], 'n/a', 0.025980493),
#   (['strange'], 'n/a', 0.02559957),
#   (['famous'], 'n/a', 0.025534028),
#   (['latest'], 'n/a', 0.0253446),
#   (['bad'], 'n/a', 0.025104428),
#   (['true'], 'n/a', 0.024759008),
#   (['good'], 'n/a', 0.02464292),
#   (['great'], 'n/a', 0.024349876)])

# %%
line = 3
qud = 0
vals = params.uncompressed[line][qud]
# vals
print(params.subspace_means[line][qud])
# hm = matplotlib.pyplot.scatter(x=(np.arange(-50,50)*0.4)+params.subspace_prior_means[line][0],y=vals)
vals = params.marginals[line]
hm = matplotlib.pyplot.scatter(x=(np.arange(-50,50)*0.4)+params.subspace_prior_means[line][0],y=vals)
# Out:
# 3.3796188831329346

# %%
line = 0
qud = 0
vals = params.uncompressed[line][qud]
# vals
# print(params.subspace_means[line][qud])
# hm = matplotlib.pyplot.scatter(x=(np.arange(-50,50)*0.4)+params.subspace_prior_means[line][0],y=vals)
vals = params.marginals[line]
hm = matplotlib.pyplot.scatter(x=(np.arange(-50,50)*0.4)+params.subspace_prior_means[line][0],y=vals)
# print((np.arange(-50,50)*0.4)+params.subspace_prior_means[line][0])
print(params.subspace_means[line][qud])
print(params.subspace_prior_means[line][qud])

# %%
vals = params.marginals[line]
hm = matplotlib.pyplot.scatter(x=(np.arange(-50,50)*0.4)+params.subspace_prior_means[line][0],y=vals)

# %%
# params.subspace_prior_means.shape
vals = scipy.stats.multivariate_normal.pdf(np.arange(-50,50)+params.subspace_prior_means[3][0],mean=params.subspace_prior_means[3][0],cov=20.0)
hm = matplotlib.pyplot.scatter(x=np.arange(-50,50)+params.subspace_prior_means[3][0],y=vals)

# %%
# Out:
# (20,)

# %%
hm = matplotlib.pyplot.scatter(x=np.arange(-10,10)+params.subspace_prior_means[0],y=vals)
# hm.show()

# %%
# prior
hm_2 = matplotlib.pyplot.scatter(x=np.arange(-10,10)+params.subspace_prior_means[0],y=vals_2)
