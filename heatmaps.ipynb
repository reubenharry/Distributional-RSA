# %%
import pickle
import pandas as pnd
import numpy as np
import matplotlib.pyplot as plt
import seaborn
from dist_rsa.models.debugging.l1_discrete import l1_model
# %matplotlib inline
# Out:
# /Users/reuben/py3/lib/python3.4/importlib/_bootstrap.py:321: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   return f(*args, **kwds)

# %%
def titrate(size,amount,l1_sig1,quds,only_trivial,pred,just_s1,possible_utterances,just_l0=False,sig1=0.1,sig2=0.1,prior=False):
    results = l1_model(subj="subj1",
                             pred=pred,
                             sig1=sig1,
                             sig2=sig2,
                             l1_sig1=l1_sig1,
                             resolution=(size,amount),
                             quds=quds,
                             only_trivial=only_trivial,
                             just_s1=just_s1,
                             just_l0=just_l0,
                             possible_utterances=possible_utterances
                            )


#     n=np.asarray([1 if x[1]==3 or x[0]==3 else 0 for x in results[1]])
# #     print(results[0].shape)
# #     print(n.shape)
#     print("\n\n\nRESULTS\n\n\n")
#     print(n)
#     n=np.reshape(n,(size*2,size*2))
    
#     hm = pnd.DataFrame(n,columns=np.arange(-size,size)*amount,index=np.arange(-size,size)*amount)
#     seaborn.heatmap(hm)
    
#     return None

    if not prior:
        pass
#         results[0][size,:]=1
#         results[0][:,size]=1
#         results[0][size,size+3]=2
#         results[0][size,size+1]=2
        hm = pnd.DataFrame(results[0],columns=np.arange(-size,size)*amount,index=np.arange(-size,size)*amount)
        seaborn.heatmap(hm)
    
#     hm = pnd.DataFrame(results[1],columns=np.arange(-size,size)*amount,index=np.arange(-size,size)*amount)
#     seaborn.heatmap(hm)

    else:

        hm = pnd.DataFrame(results[2],columns=np.arange(-size,size)*amount,index=np.arange(-size,size)*amount)
        seaborn.heatmap(hm)

# %%
titrate(size=100,amount=0.05,l1_sig1=1.0,quds=['vicious',"swims"],possible_utterances=["shark","fish"],pred='shark',only_trivial=False,just_s1=False,just_l0=False,sig1=2.0,sig2=2.0,prior=False)
# Out:
# UTTERANCES:
#  ['shark', 'fish']
# subject: ['subj1']
# predicate shark
# SIGs 1&2: 2.0 2.0
# L1 SIG 1.0
# step_size 0.1
# utt weight, qud weight 0.0 0.0
# number of qud dimensions: 1
# trival qud prior on? False
# rationality: 1.0
# sample number 2000
# Running categorical RSA with 2 possible utterances and 2
# (2, 2, 2) (2, 1, 2)

# %%
titrate(size=100,amount=0.05,l1_sig1=1.0,quds=['vicious',"swims"],possible_utterances=["shark","fish"],pred='fish',only_trivial=False,just_s1=False,just_l0=False,sig1=2.0,sig2=2.0,prior=False)
# Out:
# UTTERANCES:
#  ['shark', 'fish']
# subject: ['subj1']
# predicate fish
# SIGs 1&2: 2.0 2.0
# L1 SIG 1.0
# step_size 0.1
# utt weight, qud weight 0.0 0.0
# number of qud dimensions: 1
# trival qud prior on? False
# rationality: 1.0
# sample number 2000
# Running categorical RSA with 2 possible utterances and 2
# (2, 2, 2) (2, 1, 2)

# %%
titrate(size=100,amount=0.1,l1_sig1=1.0,quds=['vicious'],possible_utterances=["shark","fish"],pred='shark',only_trivial=False,just_s1=True,just_l0=False,sig1=2.0,sig2=2.0,prior=False)
# Out:
# UTTERANCES:
#  ['shark', 'fish']
# subject: ['subj1']
# predicate shark
# SIGs 1&2: 2.0 2.0
# L1 SIG 1.0
# step_size 0.1
# utt weight, qud weight 0.0 0.0
# number of qud dimensions: 1
# trival qud prior on? False
# rationality: 1.0
# sample number 2000
# Running categorical RSA with 2 possible utterances and 1
# (1, 2, 2) (1, 1, 2)
#
#
#
# QUDS
#
#
#  ['vicious']

# %%
titrate(size=100,amount=0.1,l1_sig1=1.0,quds=['vicious'],possible_utterances=["shark","fish"],pred='shark',only_trivial=False,just_s1=True,just_l0=False,sig1=2.0,sig2=2.0,prior=False)
# Out:
# UTTERANCES:
#  ['shark', 'fish']
# subject: ['subj1']
# predicate shark
# SIGs 1&2: 2.0 2.0
# L1 SIG 1.0
# step_size 0.1
# utt weight, qud weight 0.0 0.0
# number of qud dimensions: 1
# trival qud prior on? False
# rationality: 1.0
# sample number 2000
# Running categorical RSA with 2 possible utterances and 1
# (1, 2, 2) (1, 1, 2)
#
#
#
# QUDS
#
#
#  ['vicious']

# %%
titrate(size=100,amount=1.0,l1_sig1=10.0,quds=['vicious',"swims"],possible_utterances=["shark","fish"],pred='shark',only_trivial=False,just_s1=False,just_l0=False,sig1=0.001,sig2=0.001,prior=False)
# Out:
# UTTERANCES:
#  ['shark', 'fish']
# subject: ['subj1']
# predicate shark
# SIGs 1&2: 0.001 0.001
# L1 SIG 10.0
# step_size 0.1
# utt weight, qud weight 0.0 0.0
# number of qud dimensions: 1
# trival qud prior on? False
# rationality: 1.0
# sample number 2000
# Running categorical RSA with 2 possible utterances and 2
# (2, 2, 2) (2, 1, 2)

# %%
titrate(size=100,amount=0.1,l1_sig1=1.0,quds=['qud1'],pred='pred2',only_trivial=False,just_s1=True,just_l0=False,sig1=2.0,sig2=2.0,prior=False)
# Out:
# UTTERANCES:
#  ['pred1', 'pred2']
# subject: ['subj1']
# predicate pred2
# SIGs 1&2: 2.0 2.0
# L1 SIG 1.0
# step_size 0.1
# utt weight, qud weight 0.0 0.0
# number of qud dimensions: 1
# trival qud prior on? False
# rationality: 1.0
# sample number 2000
# Running categorical RSA with 2 possible utterances and 1
# qud_combinations 1
# quds 1
# discrete_worlds shape (40000, 2)
# [-61.41893768 -50.91893768]
# discrete_worlds_prior.get_shape (40000,)
# (1, 2, 2) (1, 1, 2)
#
#
#
# QUDS
#
#
#  ['qud1']
# (40000, 2)
# (array([[-0.69314718, -0.69314718, -0.69314718, ..., -0.69314575,
#         -0.69314575, -0.69314575],
#        [-0.69314718, -0.69314718, -0.69314718, ..., -0.69314575,
#         -0.69314575, -0.69314575],
#        [-0.69314718, -0.69314718, -0.69314718, ..., -0.69314575,
#         -0.69314575, -0.69314575],
#        ...,
#        [-0.69314575, -0.69314575, -0.69314575, ..., -0.69314718,
#         -0.69314718, -0.69314718],
# ...

# %%
titrate(size=100,amount=0.1,l1_sig1=1.0,quds=['qud2'],pred='pred1',only_trivial=False,just_s1=True,just_l0=False,sig1=2.0,sig2=2.0,prior=False)
# Out:
# UTTERANCES:
#  ['pred1', 'pred2']
# subject: ['subj1']
# predicate pred1
# SIGs 1&2: 2.0 2.0
# L1 SIG 1.0
# step_size 0.1
# utt weight, qud weight 0.0 0.0
# number of qud dimensions: 1
# trival qud prior on? False
# rationality: 1.0
# sample number 2000
# Running categorical RSA with 2 possible utterances and 1
# qud_combinations 1
# quds 1
# discrete_worlds shape (40000, 2)
# [-61.41893768 -50.91893768]
# discrete_worlds_prior.get_shape (40000,)
# (1, 2, 2) (1, 1, 2)
#
#
#
# QUDS
#
#
#  ['qud2']
# (40000, 2)
# (array([[-5.13093567, -5.10607529, -5.08123398, ..., -0.79813886,
#         -0.78447032, -0.77095711],
#        [-5.10607529, -5.08123398, -5.05638885, ..., -0.78447032,
#         -0.77095699, -0.757599  ],
#        [-5.08123398, -5.05638885, -5.03154755, ..., -0.77095711,
#         -0.757599  , -0.74439681],
#        ...,
#        [-0.79813886, -0.78447032, -0.77095711, ..., -0.00883102,
#         -0.00861359, -0.00840378],
# ...

# %%
titrate(size=10,amount=0.1,l1_sig1=5.0,quds=['qud2'],pred='pred1',only_trivial=False,just_s1=False,sig1=0.1,sig2=0.1)
# Out:
# UTTERANCES:
#  ['pred1', 'pred2']
# subject: ['subj1']
# predicate pred1
# SIGs 1&2: 0.1 0.1
# L1 SIG 5.0
# step_size 0.1
# utt weight, qud weight 0.0 0.0
# number of qud dimensions: 1
# trival qud prior on? False
# rationality: 1.0
# sample number 2000
# Running categorical RSA with 2 possible utterances and 1
# qud_combinations 1
# quds 1
# discrete_worlds shape (400, 2)
# [-2.6083765  -2.54837656]
# discrete_worlds_prior.get_shape (400,)
# (1, 2, 2) (1, 1, 2)
# (400, 2)
# (array([[-254.67062378, -244.66287231, -234.6554718 , -224.64849854,
#         -214.64186096, -204.63565063, -194.62986755, -184.62442017,
#         -174.61949158, -164.61482239, -154.61065674, -144.60688782,
#         -134.60343933, -124.6004715 , -114.5978775 , -104.59566498,
#          -94.59387207,  -84.59247589,  -74.59147644,  -64.59088135],
#        [-244.66687012, -234.65907288, -224.65170288, -214.64468384,
#         -204.63804626, -194.63186646, -184.62602234, -174.62068176,
# ...

# %%
titrate(size=100,amount=0.1,l1_sig1=5.0,quds=['qud1'],pred='pred1',only_trivial=False,just_s1=False,sig1=0.1,sig2=0.1)
# Out:
# UTTERANCES:
#  ['pred1', 'pred2']
# subject: ['subj1']
# predicate pred1
# SIGs 1&2: 0.1 0.1
# L1 SIG 5.0
# step_size 0.1
# utt weight, qud weight 0.0 0.0
# number of qud dimensions: 1
# trival qud prior on? False
# rationality: 1.0
# sample number 2000
# Running categorical RSA with 2 possible utterances and 1
# qud_combinations 1
# quds 1
# discrete_worlds shape (40000, 2)
# [-4.94837666 -4.52837658]
# discrete_worlds_prior.get_shape (40000,)
# (1, 2, 2) (1, 1, 2)
# (40000, 2)
# (array([[-13.98373795, -13.93993759, -13.89653969, ..., -13.07775116,
#         -13.11275101, -13.1481514 ],
#        [-13.9439373 , -13.90013695, -13.85673714, ..., -13.03795242,
#         -13.07295227, -13.10835075],
#        [-13.90453911, -13.86073875, -13.81733894, ..., -12.99855232,
#         -13.03355217, -13.06895256],
#        ...,
#        [-13.86575127, -13.82195091, -13.7785511 , ..., -12.95933723,
#         -12.99433708, -13.02973938],
# ...

# %%
titrate(size=100,amount=0.1,l1_sig1=5.0,quds=['qud1','qud2'],pred='pred1',only_trivial=False,just_s1=False,sig1=0.1,sig2=0.1)
# Out:
# UTTERANCES:
#  ['pred1', 'pred2']
# subject: ['subj1']
# predicate pred1
# SIGs 1&2: 0.1 0.1
# L1 SIG 5.0
# step_size 0.1
# utt weight, qud weight 0.0 0.0
# number of qud dimensions: 1
# trival qud prior on? False
# rationality: 1.0
# sample number 2000
# Running categorical RSA with 2 possible utterances and 2
# qud_combinations 2
# quds 2
# discrete_worlds shape (40000, 2)
# [-4.94837666 -4.52837658]
# discrete_worlds_prior.get_shape (40000,)
# (2, 2, 2) (2, 1, 2)
# (40000, 2)
# (array([[-14.69494629, -14.65114594, -14.60774803, ..., -13.7889595 ,
#         -13.82395935, -13.85935974],
#        [-14.65514565, -14.61134529, -14.56794548, ..., -13.74915981,
#         -13.78415966, -13.8195591 ],
#        [-14.6157465 , -14.57194614, -14.52854633, ..., -13.70976067,
#         -13.74476051, -13.78015995],
#        ...,
#        [-14.57695961, -14.53315926, -14.48975945, ..., -12.5719347 ,
#         -12.60693455, -12.64233494],
# ...
