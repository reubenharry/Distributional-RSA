# %%
import pickle
import pandas as pnd
import numpy as np
import matplotlib.pyplot as plt
import seaborn
from dist_rsa.models.debugging.l1_discrete import l1_model

# %%
def titrate(size,amount,l1_sig1,quds,only_trivial):
    world_samples = l1_model(subj="subj1",
                             pred="pred1",
                             sig1=0.1,
                             sig2=0.1,
                             l1_sig1=l1_sig1,
                             resolution=(size,amount),
                             quds=quds,
                             only_trivial=only_trivial
                            )
    hm = pnd.DataFrame(world_samples,columns=np.arange(-size,size)*amount,index=np.arange(-size,size)*amount)
    seaborn.heatmap(hm)

# %%
titrate(size=100,amount=0.1,l1_sig1=10.0,quds=['qud1'],only_trivial=True)
# Out:
# UTTERANCES:
#  ['pred1', 'pred2']
# subject: ['subj1']
# predicate pred1
# SIGs 1&2: 0.1 0.1
# L1 SIG 10.0
# step_size 0.1
# utt weight, qud weight 0.0 0.0
# number of qud dimensions: 1
# trival qud prior on? 0.5
# rationality: 1.0
# sample number 2000
# Running categorical RSA with 2 possible utterances and 1
# qud_combinations 1
# quds 1
# discrete_worlds shape (40000, 2)
# [-3.82652378 -3.72152376]
# discrete_worlds_prior.get_shape (40000,)
# [[-11.38604164 -11.376091   -11.36624146 ..., -11.35627747 -11.36602783
#   -11.37587738]
#  [-11.37509155 -11.36514091 -11.35529137 ..., -11.34532738 -11.35507774
#   -11.36492729]
#  [-11.36424065 -11.35429001 -11.34444046 ..., -11.33447647 -11.34422684
#   -11.35407639]
#  ...,
#  [-11.15927696 -11.14932632 -11.13947678 ..., -11.12994003 -11.1396904
#   -11.14953995]
#  [-11.16802788 -11.15807724 -11.14822769 ..., -11.13869095 -11.14844131
#   -11.15829086]
#  [-11.17687798 -11.16692734 -11.15707779 ..., -11.14754105 -11.15729141
#   -11.16714096]] (200, 200)

# %%
titrate(size=100,amount=0.1,l1_sig1=4.0)
# Out:
# UTTERANCES:
#  ['pred1', 'pred2']
# subject: ['subj1']
# predicate pred1
# SIGs 1&2: 0.1 0.1
# L1 SIG 4.0
# step_size 0.1
# utt weight, qud weight 0.0 0.0
# number of qud dimensions: 1
# trival qud prior on? False
# rationality: 1.0
# sample number 2000
# Running categorical RSA with 2 possible utterances and 2
# qud_combinations 2
# quds 2
# discrete_worlds shape (40000, 2)
# [-6.086483 -5.430233]
# discrete_worlds_prior.get_shape (40000,)
# [[-16.81811523 -16.75592804 -16.69436455 ..., -16.63321304 -16.69415092
#   -16.75571442]
#  [-16.74967575 -16.68748856 -16.62592697 ..., -16.56477547 -16.62571335
#   -16.68727493]
#  [-16.68186569 -16.6196785  -16.55811501 ..., -16.4969635  -16.55790138
#   -16.61946487]
#  ...,
#  [-14.30335236 -14.24116516 -14.17960262 ..., -15.21748924 -15.27842712
#   -15.33998966]
#  [-14.35803986 -14.29585266 -14.23429012 ..., -15.27217674 -15.33311462
#   -15.39467716]
#  [-14.41335201 -14.35116386 -14.28960228 ..., -15.3274889  -15.38842678
#   -15.44998837]] (200, 200)
