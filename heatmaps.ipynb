# %%
import pickle
import pandas as pnd
import numpy as np
import matplotlib.pyplot as plt
import seaborn
from dist_rsa.models.debugging.l1_discrete import l1_model
# %matplotlib inline

# %%
def titrate(size,amount,l1_sig1,quds,only_trivial,pred,just_s1):
    world_samples = l1_model(subj="subj1",
                             pred=pred,
                             sig1=0.1,
                             sig2=0.1,
                             l1_sig1=l1_sig1,
                             resolution=(size,amount),
                             quds=quds,
                             only_trivial=only_trivial,
                             just_s1=just_s1
                            )
    hm = pnd.DataFrame(world_samples,columns=np.arange(-size,size)*amount,index=np.arange(-size,size)*amount)
    seaborn.heatmap(hm)

# %%
titrate(size=100,amount=0.1,l1_sig1=1.0,quds=['qud1'],pred='pred1',only_trivial=False,just_s1=True)
# Out:
# UTTERANCES:
#  ['pred1', 'pred2']
# subject: ['subj1']
# predicate pred1
# SIGs 1&2: 0.1 0.1
# L1 SIG 1.0
# step_size 0.1
# utt weight, qud weight 0.0 0.0
# number of qud dimensions: 1
# trival qud prior on? False
# rationality: 1.0
# sample number 2000
# Running categorical RSA with 2 possible utterances and 1
# qud_combinations 1
# quds 1
# discrete_worlds shape (40000, 2)
# [-61.41893768 -50.91893768]
# discrete_worlds_prior.get_shape (40000,)
# (1, 2, 2) (1, 1, 2)
#
#
#
# QUDS
#
#
#  ['qud1']
# [[-0.69335938 -0.69335938 -0.69335938 ..., -0.69314575 -0.69314575
#   -0.69314575]
#  [-0.69335938 -0.69335938 -0.69335938 ..., -0.69314575 -0.69314575
#   -0.69314575]
#  [-0.69335938 -0.69335938 -0.69335938 ..., -0.69314575 -0.69314575
#   -0.69314575]
#  ...,
#  [-0.69314575 -0.69314575 -0.69314575 ..., -0.69335938 -0.69335938
#   -0.69335938]
#  [-0.69314575 -0.69314575 -0.69314575 ..., -0.69335938 -0.69335938
#   -0.69335938]
#  [-0.69314575 -0.69314575 -0.69314575 ..., -0.69335938 -0.69335938
#   -0.69335938]] (200, 200)

# %%
titrate(size=100,amount=0.1,l1_sig1=100.0,quds=['qud2'],pred='pred1',only_trivial=False)
# Out:
# UTTERANCES:
#  ['pred1', 'pred2']
# subject: ['subj1']
# predicate pred1
# SIGs 1&2: 0.1 0.1
# L1 SIG 100.0
# step_size 0.1
# utt weight, qud weight 0.0 0.0
# number of qud dimensions: 1
# trival qud prior on? False
# rationality: 1.0
# sample number 2000
# Running categorical RSA with 2 possible utterances and 1
# qud_combinations 1
# quds 1
# discrete_worlds shape (40000, 2)
# [-5.530159 -5.529109]
# discrete_worlds_prior.get_shape (40000,)
# (1, 2, 2) (1, 1, 2)
# [[  -59.8608551    -69.86079407   -79.86062622 ..., -2029.85864258
#   -2039.8626709  -2049.86254883]
#  [  -49.86070633   -59.86064529   -69.86048889 ..., -2019.85852051
#   -2029.85864258 -2039.8626709 ]
#  [  -39.86066055   -49.86059952   -59.8604393  ..., -2009.85839844
#   -2019.85656738 -2029.85864258]
#  ...,
#  [   -9.8585968     -9.85849667    -9.85839844 ...,   -59.85829544
#     -69.85842896   -79.85845947]
#  [   -9.85868359    -9.85858345    -9.85848618 ...,   -49.85834122
#     -59.85847855   -69.85852051]
#  [   -9.85877228    -9.8586731     -9.85857391 ...,   -39.8584938
#     -49.85862732   -59.85866547]] (200, 200)

# %%
titrate(size=100,amount=0.1,l1_sig1=10.0,quds=['qud2'],pred='pred1',only_trivial=True)
# Out:
# UTTERANCES:
#  ['pred1', 'pred2']
# subject: ['subj1']
# predicate pred1
# SIGs 1&2: 0.1 0.1
# L1 SIG 10.0
# step_size 0.1
# utt weight, qud weight 0.0 0.0
# number of qud dimensions: 1
# trival qud prior on? False
# rationality: 1.0
# sample number 2000
# Running categorical RSA with 2 possible utterances and 1
# discrete_worlds shape (40000, 2)
# [-3.82652378 -3.72152376]
# discrete_worlds_prior.get_shape (40000,)
#
#
#
# TRIVIAL S1
#
#
#
# [[-11.38391495 -11.37591553 -11.36411667 ..., -11.3543663  -11.36411667
#   -11.37591553]
#  [-11.37491608 -11.36692047 -11.3551178  ..., -11.34536743 -11.3551178
#   -11.36692047]
#  [-11.36211777 -11.35411453 -11.34231567 ..., -11.33256531 -11.34231567
#   -11.35411453]
#  ...,
#  [-11.15736771 -11.14936447 -11.13756561 ..., -11.12781525 -11.13756561
#   -11.14936447]
#  [-11.16611481 -11.15811539 -11.14631653 ..., -11.13656616 -11.14631653
#   -11.15811539]
#  [-11.17691422 -11.16892242 -11.15711594 ..., -11.14736557 -11.15711594
#   -11.16892242]] (200, 200)
