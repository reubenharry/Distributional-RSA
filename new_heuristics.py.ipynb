# %%
import matplotlib
import matplotlib.pyplot as plt
from dist_rsa.heuristics import *
# Out:
# /home/rcohngordon/dist-rsa/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# loading vecs (load vecs): glove.6B.mean_vecs300

# %%
# lit_data,met_data = produce_trofi_data()
lit_data,met_data = produce_tsvetkov_data(our_method=True)

print(len(lit_data),len(met_data))

unzipped_lit_val_data, unzipped_met_val_data, unzipped_lit_train_data, unzipped_met_train_data, train_X,train_y,val_X,val_y,test_X,test_y = data_to_predictions(lit_data=lit_data,met_data=met_data)
# Out:
# lengths orig 110 110
# NO PROJECTION WORDS
# NO PROJECTION WORDS
# NO PROJECTION WORDS
# NO PROJECTION WORDS
# NO PROJECTION WORDS
# NO PROJECTION WORDS
# lengths 61 77
# 61 77

# %%
prior_hm = matplotlib.pyplot.scatter(c='yellow',x=unzipped_lit_train_data[0],y=unzipped_lit_train_data[1])
_ = matplotlib.pyplot.scatter(c='red',x=unzipped_met_train_data[0],y=unzipped_met_train_data[1])

# %%
prior_hm_2 = matplotlib.pyplot.scatter(c='yellow',x=unzipped_lit_val_data[0],y=unzipped_lit_val_data[1])
_ = matplotlib.pyplot.scatter(c='red',x=unzipped_met_val_data[0],y=unzipped_met_val_data[1])

# %%
from sklearn.linear_model import Perceptron,LogisticRegression
clf = LogisticRegression(tol=1e-3, random_state=0)

# X = np.expand_dims(np.asarray(unzipped_train_data[0]),1)
# y = np.asarray(unzipped_train_data[1])

# print(X.shape)
# print(X)
# print(y)
clf.fit(train_X, train_y)
# pred = clf.predict([val_X[1]])
# truth = val_y[1]
# print(pred,truth)
clf.score(val_X,val_y)
# clf.score(train_X,train_y)
# Out:
# /home/rcohngordon/dist-rsa/lib/python3.5/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.5384615384615384

# %%
# lit_data,met_data = produce_trofi_data()
lit_data,met_data = produce_tsvetkov_data(our_method=True)

print(len(lit_data),len(met_data))

unzipped_lit_val_data, unzipped_met_val_data, unzipped_lit_train_data, unzipped_met_train_data, train_X,train_y,val_X,val_y,test_X,test_y = data_to_predictions(lit_data=lit_data,met_data=met_data)
# Out:
# lengths orig 110 110
# NO PROJECTION WORDS
# NO PROJECTION WORDS
# NO PROJECTION WORDS
# NO PROJECTION WORDS
# NO PROJECTION WORDS
# NO PROJECTION WORDS
# lengths 61 77
# 61 77

# %%
prior_hm = matplotlib.pyplot.scatter(c='yellow',x=unzipped_lit_train_data[0],y=unzipped_lit_train_data[1])
_ = matplotlib.pyplot.scatter(c='red',x=unzipped_met_train_data[0],y=unzipped_met_train_data[1])

# %%
lit_data,met_data = produce_trofi_data(our_method=True)

# lit_data,met_data = produce_tsvetkov_data(our_method=False)
print(len(lit_data),len(met_data))

unzipped_lit_val_data, unzipped_met_val_data, unzipped_lit_train_data, unzipped_met_train_data, train_X,train_y,val_X,val_y,test_X,test_y = data_to_predictions(lit_data=lit_data,met_data=met_data)
print(unzipped_lit_train_data[0][0])
# Out:
# NEXT TROFI ITEM
# {'nsubj': [], 'sent': ['energy', 'department', 'spokesman', 'says', 'sulfur', 'dioxide', 'might', 'simultaneously', 'recoverable', 'use', 'powdered', 'limestone', 'tends', 'absorb', 'sulfur', './.'], 'verb': 'absorb', 'dobj': ['sulfur']}
# ['department', 'dioxide', 'energy', 'limestone', 'might', 'powdered', 'recoverable', 'says', 'simultaneously', 'spokesman', 'tends', 'use']
# NEXT TROFI ITEM
# {'nsubj': ['the', 'yellow', 'beta', 'carotene', 'pigment'], 'sent': ['the', 'yellow', 'beta', 'carotene', 'pigment', 'absorbs', 'blue', '-lrb-', 'yellow', '-rrb-', 'laser', 'light', './.'], 'verb': 'absorb', 'dobj': ['blue', '-lrb-']}
# ['absorbs', 'laser', 'light']
# NEXT TROFI ITEM
# {'nsubj': ['ground'], 'sent': ['this', 'time', 'ground', 'absorbed', 'shock', 'waves', 'enough', 'transfer', 'images', 'metal', 'bas', 'relief', './.'], 'verb': 'absorb', 'dobj': ['shock', 'waves', 'enough', 'transfer', 'images', 'metal', 'bas', 'relief']}
# ['absorbed', 'this', 'time']
# ...

# %%
prior_hm = matplotlib.pyplot.scatter(c='yellow',x=unzipped_lit_train_data[0][:300],y=unzipped_lit_train_data[1][:300])
_ = matplotlib.pyplot.scatter(c='red',x=unzipped_met_train_data[0][:300],y=unzipped_met_train_data[1][:300])
